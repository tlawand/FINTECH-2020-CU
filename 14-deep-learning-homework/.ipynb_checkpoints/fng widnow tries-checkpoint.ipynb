# %%
import numpy as np
import pandas as pd
import hvplot.pandas

# %matplotlib inline

# %%
# Set the random seed for reproducibility
# Note: This is for the homework solution, but it is good practice to comment this out and run multiple experiments to evaluate your model
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)

# %%
# Load the fear and greed sentiment data for Bitcoin
df = pd.read_csv('btc_sentiment.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df = df.drop(columns="fng_classification")

# %%
# Load the historical closing prices for Bitcoin
df2 = pd.read_csv('btc_historic.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)['Close']
df2 = df2.sort_index()

# %%
# Join the data into a single DataFrame
df = df.join(df2, how="inner")

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of fear and greed index values and a target of the 11th day closing price
# Try a window size anywhere from 1 to 10 and see how the model performance changes

for window in range(1,11):
    # Column index 1 is the `Close` column
    window_size = window
    feature_column = 0
    target_column = 1
    X, y = window_data(df, window_size, feature_column, target_column)
    
    # Use 70% of the data for training and the remainder for testing
    split = int(0.7 * len(X))
    X_train = X[: split - 1]
    X_test = X[split:]
    y_train = y[: split - 1]
    y_test = y[split:]
    
    # Use MinMaxScaler to scale the data between 0 and 1.
    from sklearn.preprocessing import MinMaxScaler
    
    scaler = MinMaxScaler()
    scaler.fit(X)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    scaler.fit(y)
    y_train = scaler.transform(y_train)
    y_test = scaler.transform(y_test)
    
    # Reshape the features for the model
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense, Dropout
    
    # Build the LSTM model. 
    # The return sequences need to be set to True if you are adding additional LSTM layers, but 
    # You don't have to do this for the final layer. 
    model = Sequential()

    number_units = 30
    dropout_fraction = 0.2

    # Layer 1
    model.add(LSTM(
        units=number_units,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    # Layer 2
    model.add(LSTM(units=number_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # Layer 3
    model.add(LSTM(units=number_units))
    model.add(Dropout(dropout_fraction))
    # Output layer
    model.add(Dense(1))
    
    # Compile the model
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    # Train the model
    # Use at least 10 epochs
    # Do not shuffle the data
    # Experiement with the batch size, but a smaller batch size is recommended
    model.fit(X_train, y_train, epochs=20, shuffle=False, batch_size=1, verbose=1)
    
    # Evaluate the model
    model.evaluate(X_test, y_test)
    
    # Make some predictions
    predicted = model.predict(X_test)
    
    # Recover the original prices instead of the scaled version
    predicted_prices = scaler.inverse_transform(predicted)
    real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
    
    # Create a DataFrame of Real and Predicted values
    stocks = pd.DataFrame({
        "Real": real_prices.ravel(),
        "Predicted": predicted_prices.ravel()
    })
    stocks.head()
    
    # Plot the real vs predicted values as a line chart
    stocks.plot()
# Out:
# Epoch 1/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0529
# Epoch 2/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0311
# Epoch 3/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0291
# Epoch 4/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0277
# Epoch 5/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0277
# Epoch 6/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0265
# Epoch 7/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0264
# Epoch 8/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0272
# Epoch 9/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0266
# Epoch 10/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0267
# Epoch 11/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0273
# Epoch 12/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0282
# Epoch 13/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0283
# Epoch 14/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0288
# Epoch 15/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0296
# Epoch 16/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0295
# Epoch 17/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0308
# Epoch 18/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0307
# Epoch 19/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0304
# Epoch 20/20
# 377/377 [==============================] - 1s 2ms/step - loss: 0.0327
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0961
# Epoch 1/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0359
# Epoch 2/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0230
# Epoch 3/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0255
# Epoch 4/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0250
# Epoch 5/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0261
# Epoch 6/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0253
# Epoch 7/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0253
# Epoch 8/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0251
# Epoch 9/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0264
# Epoch 10/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0267
# Epoch 11/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0285
# Epoch 12/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0292
# Epoch 13/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0299
# Epoch 14/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0304
# Epoch 15/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0300
# Epoch 16/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0314
# Epoch 17/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0317
# Epoch 18/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0313
# Epoch 19/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0333
# Epoch 20/20
# 377/377 [==============================] - 1s 3ms/step - loss: 0.0331
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1014
# Epoch 1/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0298
# Epoch 2/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0218
# Epoch 3/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0263
# Epoch 4/20
# 376/376 [==============================] - 1s 4ms/step - loss: 0.0259
# Epoch 5/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0253
# Epoch 6/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0249
# Epoch 7/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0262
# Epoch 8/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0256
# Epoch 9/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0263
# Epoch 10/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0281
# Epoch 11/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0298
# Epoch 12/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0293
# Epoch 13/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0304
# Epoch 14/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0310
# Epoch 15/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0321
# Epoch 16/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0328
# Epoch 17/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0327
# Epoch 18/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0335
# Epoch 19/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0336
# Epoch 20/20
# 376/376 [==============================] - 1s 3ms/step - loss: 0.0341
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1089
# Epoch 1/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0270
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0215
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0274
# Epoch 4/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0268
# Epoch 5/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0259
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0246
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0247
# Epoch 8/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0228
# Epoch 9/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0239
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0245
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0267
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0277
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0326
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0334
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0346
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0346
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0341
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0355
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0343
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0350
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1156
# Epoch 1/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0257
# Epoch 2/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0230
# Epoch 3/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0270
# Epoch 4/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0268
# Epoch 5/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0224
# Epoch 6/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0233
# Epoch 7/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0246
# Epoch 8/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0249
# Epoch 9/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0237
# Epoch 10/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0244
# Epoch 11/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0268
# Epoch 12/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0296
# Epoch 13/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0347
# Epoch 14/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0334
# Epoch 15/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0339
# Epoch 16/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0347
# Epoch 17/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0347
# Epoch 18/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0348
# Epoch 19/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0358
# Epoch 20/20
# 374/374 [==============================] - 1s 4ms/step - loss: 0.0346
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1132
# Epoch 1/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0236
# Epoch 2/20
# 374/374 [==============================] - 2s 5ms/step - loss: 0.0228
# Epoch 3/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0280
# Epoch 4/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0279
# Epoch 5/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0242
# Epoch 6/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0235
# Epoch 7/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0235
# Epoch 8/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0237
# Epoch 9/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0233
# Epoch 10/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0236
# Epoch 11/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0257
# Epoch 12/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0304
# Epoch 13/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0363
# Epoch 14/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0369
# Epoch 15/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0343
# Epoch 16/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0371
# Epoch 17/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0370
# Epoch 18/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0374
# Epoch 19/20
# 374/374 [==============================] - 2s 4ms/step - loss: 0.0351
# Epoch 20/20
# 374/374 [==============================] - 2s 5ms/step - loss: 0.0355
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1101
# Epoch 1/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0245
# Epoch 2/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0228
# Epoch 3/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0263
# Epoch 4/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0276
# Epoch 5/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0257
# Epoch 6/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0243
# Epoch 7/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0229
# Epoch 8/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0228
# Epoch 9/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0234
# Epoch 10/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0261
# Epoch 11/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0265
# Epoch 12/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0299
# Epoch 13/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0314
# Epoch 14/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0367
# Epoch 15/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0379
# Epoch 16/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0355
# Epoch 17/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0365
# Epoch 18/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0363
# Epoch 19/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0367
# Epoch 20/20
# 373/373 [==============================] - 2s 5ms/step - loss: 0.0378
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1176
# Epoch 1/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0193
# Epoch 2/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0207
# Epoch 3/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0246
# Epoch 4/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0262
# Epoch 5/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0239
# Epoch 6/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0234
# Epoch 7/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0234
# Epoch 8/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0223
# Epoch 9/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0221
# Epoch 10/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0241
# Epoch 11/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0228
# Epoch 12/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0252
# Epoch 13/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0268
# Epoch 14/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0318
# Epoch 15/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0361
# Epoch 16/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0367
# Epoch 17/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0388
# Epoch 18/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0365
# Epoch 19/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0378
# Epoch 20/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0372
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1186
# Epoch 1/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0230
# Epoch 2/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0235
# Epoch 3/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0282
# Epoch 4/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 5/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0268
# Epoch 6/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0260
# Epoch 7/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0274
# Epoch 8/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0249
# Epoch 9/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0240
# Epoch 10/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0256
# Epoch 11/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0243
# Epoch 12/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0261
# Epoch 13/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0339
# Epoch 14/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0428
# Epoch 15/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0444
# Epoch 16/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0438
# Epoch 17/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0400
# Epoch 18/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0479
# Epoch 19/20
# 372/372 [==============================] - 2s 6ms/step - loss: 0.0451
# Epoch 20/20
# 372/372 [==============================] - 2s 5ms/step - loss: 0.0446
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1037
# Epoch 1/20
# 371/371 [==============================] - 2s 7ms/step - loss: 0.0210
# Epoch 2/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0237
# Epoch 3/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0270
# Epoch 4/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0262
# Epoch 5/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0288
# Epoch 6/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0289
# Epoch 7/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0276
# Epoch 8/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0267
# Epoch 9/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0263
# Epoch 10/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0272
# Epoch 11/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0289
# Epoch 12/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0354
# Epoch 13/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0384
# Epoch 14/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0362
# Epoch 15/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0361
# Epoch 16/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0447
# Epoch 17/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0397
# Epoch 18/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0392
# Epoch 19/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0346
# Epoch 20/20
# 371/371 [==============================] - 2s 6ms/step - loss: 0.0348
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1156
